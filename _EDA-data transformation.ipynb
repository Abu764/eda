# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path=r"C:\Users\Mohammed Abubakar\OneDrive\file handing\Visadataset.csv"

# %% [markdown]
# Exponential − data

# %%
exp_data=np.random.exponential(size=10000)
exp_data[:10]
# Out:
# array([0.12082756, 2.04387917, 3.94855008, 0.55078148, 0.04397872,
#        0.54490466, 3.09019182, 0.49180844, 1.2102295 , 0.36871934])

# %%
plt.hist(exp_data,bins=30,label='Exponential')
plt.legend()
plt.show()

# %% [markdown]
# Norm − data

# %%
norm_data=np.random.normal(size=1000)
plt.hist(norm_data)
# Out:
# (array([  8.,  31.,  89., 187., 209., 225., 135.,  88.,  21.,   7.]),
#  array([-2.90903102, -2.31400682, -1.71898262, -1.12395842, -0.52893422,
#          0.06608998,  0.66111418,  1.25613838,  1.85116258,  2.44618678,
#          3.04121098]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Log Transformaton

# %%
log_data=np.log(exp_data)
log_data[:10]
# Out:
# array([-2.11339087,  0.71484956,  1.37334844, -0.59641713, -3.12404948,
#        -0.60714443,  1.12823317, -0.709666  ,  0.19081001, -0.99771951])

# %%
exp_data[:10]
# Out:
# array([0.12082756, 2.04387917, 3.94855008, 0.55078148, 0.04397872,
#        0.54490466, 3.09019182, 0.49180844, 1.2102295 , 0.36871934])

# %%
plt.hist(log_data,bins=40,label='Log data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,
bins=40,

label='Exponential')

plt.legend()
plt.subplot(1,2,2).hist(log_data,
bins=40,

label='Log Transformation')

plt.legend()
plt.show()

# %% [markdown]
# Reciprocal transformation

# %%
x=3
np.reciprocal(x)
# Out:
# 0

# %%
rec_data=np.reciprocal(exp_data)

# %%
exp_data,rec_data
# Out:
# (array([0.12082756, 2.04387917, 3.94855008, ..., 0.49292628, 1.24288411,
#         1.64336221]),
#  array([8.27625743, 0.48926571, 0.25325752, ..., 2.02870092, 0.80458025,
#         0.60850858]))

# %%
8/0.120
# Out:
# 66.66666666666667

# %%
exp_data[:2]
# Out:
# array([0.12082756, 2.04387917])

# %% [markdown]
# Square root transformation

# %%
print(25**2) 
print(25**(1/2)) 
print(np.sqrt(25))
# Out:
# 625
# 5.0
# 5.0

# %%
sqrt_data=np.sqrt(exp_data)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,
bins=40,

label='Exponential')

plt.legend()
plt.subplot(1,2,2).hist(sqrt_data,
bins=40,

label='Sqaure root Transformation')

plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
sns.histplot(sqrt_data)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Power transformer

# %%
exp_data
# Out:
# array([0.12082756, 2.04387917, 3.94855008, ..., 0.49292628, 1.24288411,
#        1.64336221])

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
pt_data=pt.fit([exp_data]).transform([exp_data])

# %%
pt_data
# Out:
# array([[-4.16333634e-17,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00, -2.22044605e-16, -2.22044605e-16]])

# %%
                
plt.hist(pt_data[0])
plt.show()
